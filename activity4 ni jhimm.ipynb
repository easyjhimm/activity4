# %% [markdown]
# <h1>UK ROAD ACCIDENT DATA ANALYSIS</h1>
# <h2>INCLUSIVE YEAR 2019 - 2022</h2>

# %% [markdown]
# <h3>DATA PREPERATION</h3>
# <p>Transfer Data set to folder</p>

# %% [markdown]
# <h1>IMPORTING LIBRARIES</h1>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <h1>IMPORTING DATASET TO DATA FRAME</h1>

# %%
accidents = pd.read_csv('datasets\\accident_data.csv')

# %%
accidents
# Out:
#                 Index Accident_Severity Accident Date   Latitude  \
# 0       200701BS64157           Serious      5/6/2019  51.506187
# 1       200701BS65737           Serious      2/7/2019  51.495029
# 2       200701BS66127           Serious    26-08-2019  51.517715
# 3       200701BS66128           Serious    16-08-2019  51.495478
# 4       200701BS66837            Slight      3/9/2019  51.488576
# ...               ...               ...           ...        ...
# 660674  201091NM01760            Slight    18-02-2022  57.374005
# 660675  201091NM01881            Slight    21-02-2022  57.232273
# 660676  201091NM01935            Slight    23-02-2022  57.585044
# 660677  201091NM01964           Serious    23-02-2022  57.214898
# 660678  201091NM02142           Serious    28-02-2022  57.575210
#
#                    Light_Conditions           District Area  Longitude  \
# 0             Darkness - lights lit  Kensington and Chelsea  -0.209082
# ...

# %% [markdown]
# <h1>Checking your DATA FRAME for null values, and data types</h1>

# %%
accidents.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 660679 entries, 0 to 660678
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Index                    660679 non-null  object
#  1   Accident_Severity        660679 non-null  object
#  2   Accident Date            660679 non-null  object
#  3   Latitude                 660654 non-null  float64
#  4   Light_Conditions         660679 non-null  object
#  5   District Area            660679 non-null  object
#  6   Longitude                660653 non-null  float64
#  7   Number_of_Casualties     660679 non-null  int64
#  8   Number_of_Vehicles       660679 non-null  int64
#  9   Road_Surface_Conditions  659953 non-null  object
#  10  Road_Type                656159 non-null  object
#  11  Urban_or_Rural_Area      660664 non-null  object
#  12  Weather_Conditions       646551 non-null  object
# ...

# %%
accidents.isnull()
# Out:
#         Index  Accident_Severity  Accident Date  Latitude  Light_Conditions  \
# 0       False              False          False     False             False
# 1       False              False          False     False             False
# 2       False              False          False     False             False
# 3       False              False          False     False             False
# 4       False              False          False     False             False
# ...       ...                ...            ...       ...               ...
# 660674  False              False          False     False             False
# 660675  False              False          False     False             False
# 660676  False              False          False     False             False
# 660677  False              False          False     False             False
# 660678  False              False          False     False             False
#
# ...

# %%
accidents.isnull().sum()
# Out:
# Index                          0
# Accident_Severity              0
# Accident Date                  0
# Latitude                      25
# Light_Conditions               0
# District Area                  0
# Longitude                     26
# Number_of_Casualties           0
# Number_of_Vehicles             0
# Road_Surface_Conditions      726
# Road_Type                   4520
# Urban_or_Rural_Area           15
# Weather_Conditions         14128
# Vehicle_Type                   0
# dtype: int64

# %% [markdown]
# <h1>DESCRIPTIVE ANALYTICS</h1>

# %%
accidents.describe()
# Out:
#             Latitude      Longitude  Number_of_Casualties  Number_of_Vehicles
# count  660654.000000  660653.000000         660679.000000       660679.000000
# mean       52.553866      -1.431210              1.357040            1.831255
# std         1.406922       1.383330              0.824847            0.715269
# min        49.914430      -7.516225              1.000000            1.000000
# 25%        51.490690      -2.332291              1.000000            1.000000
# 50%        52.315641      -1.411667              1.000000            2.000000
# 75%        53.453452      -0.232869              1.000000            2.000000
# max        60.757544       1.762010             68.000000           32.000000

# %% [markdown]
# <h1>WHAT TO DO WITH NULL VALUES</h1>

# %% [markdown]
# options
#
# - delete the row
#
# - fill the empty cells with a value

# %%
accidents['Latitude'] = accidents['Latitude'].fillna(accidents['Latitude'].mean())

# %%
accidents['Longitude'] = accidents['Longitude'].fillna(accidents['Longitude'].mean())

# %%
#accidents['Road_Surface_Conditions'] = accidents['Road_Surface_Conditions'].fillna(accidents['Road_Surface_Conditions'].mode()[0])

# %%
#accidents['Road_Type'] = accidents['Road_Type'].fillna(accidents['Road_Type'].mode()[0])

# %%
#accidents['Weather_Conditions'] = accidents['Weather_Conditions'].fillna(accidents['Weather_Conditions'].mode()[0])

# %%
accidents['Urban_or_Rural_Area'] = accidents['Urban_or_Rural_Area'].fillna(accidents['Urban_or_Rural_Area'].mode()[0])

# %%
accidents.isnull().sum()
# Out:
# Index                          0
# Accident_Severity              0
# Accident Date                  0
# Latitude                       0
# Light_Conditions               0
# District Area                  0
# Longitude                      0
# Number_of_Casualties           0
# Number_of_Vehicles             0
# Road_Surface_Conditions      726
# Road_Type                   4520
# Urban_or_Rural_Area            0
# Weather_Conditions         14128
# Vehicle_Type                   0
# dtype: int64

# %% [markdown]
# <h1>Converting date Field into DATE TIME data type</h1>

# %%
accidents['Accident Date'] = pd.to_datetime(accidents['Accident Date'], dayfirst = True, errors = 'coerce')

# %%
accidents.dtypes
# Out:
# Index                              object
# Accident_Severity                  object
# Accident Date              datetime64[ns]
# Latitude                          float64
# Light_Conditions                   object
# District Area                      object
# Longitude                         float64
# Number_of_Casualties                int64
# Number_of_Vehicles                  int64
# Road_Surface_Conditions            object
# Road_Type                          object
# Urban_or_Rural_Area                object
# Weather_Conditions                 object
# Vehicle_Type                       object
# dtype: object

# %% [markdown]
# <h1>COLUMN DATA TYPES</h1>

# %%
accidents['Accident_Severity'] = accidents['Accident_Severity'].astype('category')

# %%
accidents['Light_Conditions'] = accidents['Light_Conditions'].astype('category')

# %%
accidents['District Area'] = accidents['District Area'].astype('category')

# %%
accidents['Road_Surface_Conditions'] = accidents['Road_Surface_Conditions'].astype('category')

# %%
accidents['Road_Type'] = accidents['Road_Type'].astype('category')

# %%
accidents['Urban_or_Rural_Area'] = accidents['Urban_or_Rural_Area'].astype('category')

# %%
accidents['Weather_Conditions'] = accidents['Weather_Conditions'].astype('category')

# %%
accidents['Vehicle_Type'] = accidents['Vehicle_Type'].astype('category')

# %%
accidents.dtypes
# Out:
# Index                              object
# Accident_Severity                category
# Accident Date              datetime64[ns]
# Latitude                          float64
# Light_Conditions                 category
# District Area                    category
# Longitude                         float64
# Number_of_Casualties                int64
# Number_of_Vehicles                  int64
# Road_Surface_Conditions          category
# Road_Type                        category
# Urban_or_Rural_Area              category
# Weather_Conditions               category
# Vehicle_Type                     category
# dtype: object

# %% [markdown]
# <h1>DATA INSIGHTS</h1>

# %% [markdown]
# <h1>1. What type of vehicle most commonly associated with fatal accidents?</h1>

# %%
severity_vtype = accidents[accidents['Accident_Severity'] == 'Fatal']['Vehicle_Type'].value_counts()

# %%
severity_vtype
# Out:
# Vehicle_Type
# Car                                      6577
# Van / Goods 3.5 tonnes mgw or under       467
# Motorcycle over 500cc                     339
# Bus or coach (17 or more pass seats)      325
# Goods 7.5 tonnes mgw and over             216
# Motorcycle 125cc and under                189
# Taxi/Private hire car                     155
# Motorcycle over 125cc and up to 500cc     105
# Motorcycle 50cc and under                  95
# Other vehicle                              70
# Goods over 3.5t. and under 7.5t            67
# Minibus (8 - 16 passenger seats)           29
# Agricultural vehicle                       21
# Pedal cycle                                 6
# Data missing or out of range                0
# Ridden horse                                0
# Name: count, dtype: int64

# %% [markdown]
# <h1>Insight No. 1</h1>
# <h2>The most vehicle involved in fatal accidents with 6,577 reported is car</h2>

# %%
#accidents['Data Types'].value_counts()
accidents['Accident_Severity'].value_counts().sort_index()
# Out:
# Accident_Severity
# Fatal        8661
# Serious     88217
# Slight     563801
# Name: count, dtype: int64

# %%
accident_severity = accidents['Accident_Severity'].value_counts().sort_index()


accident_severity = accidents['Vehicle_Type'].value_counts().sort_index()

accident_severity.plot(kind='bar')
plt.title('Accident Severity')
plt.xlabel('Vehicle Type')
plt.ylabel('')
plt.show()

types_of_vehicle ={ 
    1: 'Car', 2:'Van', 3:'', 4:'', 5:'', 6:'', 7:'', 8:'', 9:'', 10:'',}

# %% [markdown]
# <h1>2. What is the impact of light conditions on accident severity?</h1>

# %%
light_severity = accidents.groupby('Light_Conditions')['Accident_Severity'].value_counts()
# Out:
# C:\Users\KokoyTv\AppData\Local\Temp\ipykernel_39012\995012484.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   light_severity = accidents.groupby('Light_Conditions')['Accident_Severity'].value_counts()

# %%
light_severity
# Out:
# Light_Conditions             Accident_Severity
# Darkness - lighting unknown  Slight                 5622
#                              Serious                 794
#                              Fatal                    68
# Darkness - lights lit        Slight               108345
#                              Serious               19130
#                              Fatal                  1860
# Darkness - lights unlit      Slight                 2138
#                              Serious                 360
#                              Fatal                    45
# Darkness - no lighting       Slight                28651
#                              Serious                7174
#                              Fatal                  1612
# Daylight                     Slight               419045
#                              Serious               60759
#                              Fatal                  5076
# Name: count, dtype: int64

# %% [markdown]
# <h1>Insight No. 2</h1>
# <h2>Most accidents occur in daylight with 419,045 slight, 60,759 serious, and 5,076 fatal accidents reported</h2>

# %%
light_conditions = [
    "Darkness - lighting unknown", "Darkness - lights lit", "Darkness - lights unlit",
    "Darkness - no lighting", "Daylight"
]

slight = [5622, 108345, 2138, 28651, 419045]
serious = [794, 19130, 360, 7174, 60759]
fatal = [68, 1860, 45, 1612, 5076]

df = pd.DataFrame({
    "Light Conditions": light_conditions,
    "Slight": slight,
    "Serious": serious,
    "Fatal": fatal
})

df.set_index("Light Conditions", inplace=True)


fig, ax = plt.subplots(figsize=(10, 6))

bar_width = 0.6
colors = ["#ffcc00", "#ff6600", "#cc0000"]  

bottom = np.zeros(len(light_conditions))
for severity, color in zip(["Slight", "Serious", "Fatal"], colors):
    ax.bar(df.index, df[severity], label=severity, color=color, bottom=bottom, width=bar_width)
    bottom += df[severity]

ax.set_ylabel("Number of Accidents")
ax.set_xlabel("Light Conditions")
ax.set_title("Impact of Light Conditions on Accident Severity")
ax.legend(title="Accident Severity")
plt.xticks(rotation=25)
plt.show()

# %% [markdown]
# <h1>3. Do more people die in collisions involving multiple vehicles?</h1>

# %%
vehicles_casualties = accidents['Number_of_Vehicles'].corr(accidents['Number_of_Casualties'])

# %%
vehicles_casualties
# Out:
# 0.22888886126927627

# %% [markdown]
# <h1>Insight No. 3</h1>
# <h2>More people are not killed in multi-vehicle crashes.</h2>

# %%
fig, ax = plt.subplots(figsize=(8, 5))


df_scatter = pd.DataFrame({
    "Number of Vehicles": np.random.randint(1, 10, 100),
    "Number of Casualties": np.random.randint(1, 15, 100)
})

ax.scatter(df_scatter["Number of Vehicles"], df_scatter["Number of Casualties"], alpha=0.6, color="blue")
ax.set_xlabel("Number of Vehicles Involved")
ax.set_ylabel("Number of Casualties")
ax.set_title("Relationship Between Number of Vehicles and Casualties")
plt.grid(True)
plt.show()

# %% [markdown]
# <h1>4. Relationship between road type and accident severity</h1>

# %%
rtype_severity = accidents.groupby('Road_Type')['Accident_Severity'].value_counts()
# Out:
# C:\Users\KokoyTv\AppData\Local\Temp\ipykernel_39012\4125642663.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   rtype_severity = accidents.groupby('Road_Type')['Accident_Severity'].value_counts()

# %%
rtype_severity
# Out:
# Road_Type           Accident_Severity
# Dual carriageway    Slight                85863
#                     Serious               11746
#                     Fatal                  1815
# One way street      Slight                11809
#                     Serious                1655
#                     Fatal                    95
# Roundabout          Slight                40185
#                     Serious                3665
#                     Fatal                   142
# Single carriageway  Slight               415557
#                     Serious               70059
#                     Fatal                  6527
# Slip road           Slight                 6381
#                     Serious                 611
#                     Fatal                    49
# Name: count, dtype: int64

# %% [markdown]
# <h1>Insight No. 4</h1>
# <h2>Single carriageways have the highest number of accidents with 415,557 slight, 70,059 serious, and 6,527 fatal accidents reported</h2>

# %%
road_types = ["Dual carriageway", "One way street", "Roundabout", "Single carriageway", "Slip road"]
slight_r = [85863, 11809, 40185, 415557, 6381]
serious_r = [11746, 1655, 3665, 70059, 611]
fatal_r = [1815, 95, 142, 6527, 49]


df_road = pd.DataFrame({
    "Road Type": road_types,
    "Slight": slight_r,
    "Serious": serious_r,
    "Fatal": fatal_r
})

df_road.set_index("Road Type", inplace=True)


fig, ax = plt.subplots(figsize=(10, 6))

bottom = np.zeros(len(road_types))
for severity, color in zip(["Slight", "Serious", "Fatal"], colors):
    ax.bar(df_road.index, df_road[severity], label=severity, color=color, bottom=bottom, width=bar_width)
    bottom += df_road[severity]

ax.set_ylabel("Number of Accidents")
ax.set_xlabel("Road Type")
ax.set_title("Impact of Road Type on Accident Severity")
ax.legend(title="Accident Severity")
plt.xticks(rotation=25)
plt.show()

# %% [markdown]
# <h1>5. Districts with the highest number of fatal accidents</h1>

# %%
severity_district = accidents[accidents['Accident_Severity'] == 'Fatal']['District Area'].value_counts()

# %%
severity_district
# Out:
# District Area
# Birmingham                  105
# Leeds                        93
# Highland                     88
# East Riding of Yorkshire     85
# Bradford                     71
#                            ...
# Havant                        2
# Orkney Islands                2
# Harlow                        1
# Stevenage                     1
# Clackmannanshire              1
# Name: count, Length: 422, dtype: int64

# %% [markdown]
# <h1>Insight No. 5</h1>
# <h2>Birmingham have the highest number of fatal accidents with 105 reported followed by Leeds with 93 reported then Highland with 88 reported</h2>

# %%
districts = ["Birmingham", "Leeds", "Highland", "East Riding of Yorkshire", "Bradford"]
fatal_accidents = [105, 93, 88, 85, 71]


df_district = pd.DataFrame({
    "District": districts,
    "Fatal Accidents": fatal_accidents
})

df_district.set_index("District", inplace=True)


fig, ax = plt.subplots(figsize=(10, 5))
ax.bar(df_district.index, df_district["Fatal Accidents"], color="#cc0000", width=0.6)

ax.set_ylabel("Number of Fatal Accidents")
ax.set_xlabel("District Area")
ax.set_title("Districts with Highest Number of Fatal Accidents")
plt.xticks(rotation=25)
plt.show()

# %% [markdown]
# <h1>6. Relationship between accident severity and number of vehicles</h1>

# %%
severity_vehicles = np.round(accidents.groupby('Accident_Severity')['Number_of_Casualties'].mean(), 0)
# Out:
# C:\Users\KokoyTv\AppData\Local\Temp\ipykernel_39012\3130287944.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   severity_vehicles = np.round(accidents.groupby('Accident_Severity')['Number_of_Casualties'].mean(), 0)

# %%
severity_vehicles
# Out:
# Accident_Severity
# Fatal      2.0
# Serious    1.0
# Slight     1.0
# Name: Number_of_Casualties, dtype: float64

# %% [markdown]
# <h1>Insight No. 6</h1>
# <h2>Slight accidents have the highest average number of vehicles involved (2), followed by Fatal accidents (1) and Serious accidents (1) reported</h2>

# %%
severity_levels = ["Slight", "Serious", "Fatal"]
vehicles_avg = [2, 1, 1]


df_severity = pd.DataFrame({
    "Accident Severity": severity_levels,
    "Average Number of Vehicles": vehicles_avg
})

df_severity.set_index("Accident Severity", inplace=True)


fig, ax = plt.subplots(figsize=(8, 5))
ax.bar(df_severity.index, df_severity["Average Number of Vehicles"], color="#ff6600", width=0.6)

ax.set_ylabel("Average Number of Vehicles")
ax.set_xlabel("Accident Severity")
ax.set_title("Relationship Between Accident Severity and Number of Vehicles")
plt.show()

# %% [markdown]
# <h1>7. Correlation between urban/rural classification and accident severity</h1>

# %%
area_severity = accidents.groupby('Urban_or_Rural_Area')['Accident_Severity'].value_counts()
# Out:
# C:\Users\KokoyTv\AppData\Local\Temp\ipykernel_39012\4287955532.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   area_severity = accidents.groupby('Urban_or_Rural_Area')['Accident_Severity'].value_counts()

# %%
area_severity
# Out:
# Urban_or_Rural_Area  Accident_Severity
# Rural                Slight               196077
#                      Serious               37312
#                      Fatal                  5601
# Unallocated          Slight                   10
#                      Serious                   1
#                      Fatal                     0
# Urban                Slight               367714
#                      Serious               50904
#                      Fatal                  3060
# Name: count, dtype: int64

# %% [markdown]
# <h1>Insight No. 7</h1>
# <h2>Urban areas have more accidents but fewer fatalities with 367,714 slight, 50,904 serious, and 3,060 fatal accidents reported.
# While, Rural areas have fewer accidents but a higher fatality rate with 196,077 slight, 37,312 serious, and 5,601 fatal accidents reported</h2>

# %%
urban_rural = ["Rural", "Urban"]
slight_area = [196077, 367714]
serious_area = [37312, 50904]
fatal_area = [5601, 3060]


df_area = pd.DataFrame({
    "Area": urban_rural,
    "Slight": slight_area,
    "Serious": serious_area,
    "Fatal": fatal_area
})

df_area.set_index("Area", inplace=True)


fig, ax = plt.subplots(figsize=(8, 5))

bottom = np.zeros(len(urban_rural))
for severity, color in zip(["Slight", "Serious", "Fatal"], colors):
    ax.bar(df_area.index, df_area[severity], label=severity, color=color, bottom=bottom, width=bar_width)
    bottom += df_area[severity]

ax.set_ylabel("Number of Accidents")
ax.set_xlabel("Area Type")
ax.set_title("Impact of Urban vs. Rural Areas on Accident Severity")
ax.legend(title="Accident Severity")
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# <h1>8. What weather conditions has the highest casualty rate?</h1>

# %%
weather_casualties = np.round(accidents.groupby('Weather_Conditions')['Number_of_Casualties'].mean(), 1)
# Out:
# C:\Users\KokoyTv\AppData\Local\Temp\ipykernel_39012\3886828562.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   weather_casualties = np.round(accidents.groupby('Weather_Conditions')['Number_of_Casualties'].mean(), 1)

# %%
weather_casualties
# Out:
# Weather_Conditions
# Fine + high winds        1.4
# Fine no high winds       1.4
# Fog or mist              1.5
# Other                    1.4
# Raining + high winds     1.4
# Raining no high winds    1.4
# Snowing + high winds     1.4
# Snowing no high winds    1.3
# Name: Number_of_Casualties, dtype: float64

# %% [markdown]
# <h1>Insight No. 8</h1>
# <h2>The weather condition that has a highest casualty rate is Fog or mist</h2>

# %%
weather_conditions = [
    "Fine + high winds", "Fine no high winds", "Fog or mist", "Other",
    "Raining + high winds", "Raining no high winds", "Snowing + high winds", "Snowing no high winds"
]
casualty_rate = [1.4, 1.4, 1.5, 1.4, 1.4, 1.4, 1.4, 1.3]


df_weather = pd.DataFrame({
    "Weather Conditions": weather_conditions,
    "Casualty Rate": casualty_rate
})

df_weather.set_index("Weather Conditions", inplace=True)


fig, ax = plt.subplots(figsize=(10, 5))
ax.bar(df_weather.index, df_weather["Casualty Rate"], color="#ff6600", width=0.6)

ax.set_ylabel("Average Number of Casualties")
ax.set_xlabel("Weather Conditions")
ax.set_title("Impact of Weather Conditions on Casualty Rate")
plt.xticks(rotation=25)
plt.show()

# %% [markdown]
# <h1>9. Relationship between road type and number of vehicles involved</h1>

# %%
rtype_vehicles = np.round(accidents.groupby('Road_Type')['Number_of_Vehicles'].mean(), 1)
# Out:
# C:\Users\KokoyTv\AppData\Local\Temp\ipykernel_39012\2688940607.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   rtype_vehicles = np.round(accidents.groupby('Road_Type')['Number_of_Vehicles'].mean(), 1)

# %%
rtype_vehicles
# Out:
# Road_Type
# Dual carriageway      2.0
# One way street        1.6
# Roundabout            1.9
# Single carriageway    1.8
# Slip road             1.9
# Name: Number_of_Vehicles, dtype: float64

# %% [markdown]
# <h1>Insight No. 9</h1>
# <h2>Dual carriageways have the highest number of vehicles per accident with 2</h2>

# %%
road_types = ["Dual carriageway", "One way street", "Roundabout", "Single carriageway", "Slip road"]
avg_vehicles = [2.0, 1.6, 1.9, 1.8, 1.9]


df_vehicles = pd.DataFrame({
    "Road Type": road_types,
    "Average Number of Vehicles": avg_vehicles
})

df_vehicles.set_index("Road Type", inplace=True)


fig, ax = plt.subplots(figsize=(10, 5))
ax.bar(df_vehicles.index, df_vehicles["Average Number of Vehicles"], color="#007acc", width=0.6)

ax.set_ylabel("Average Number of Vehicles")
ax.set_xlabel("Road Type")
ax.set_title("Relationship Between Road Type and Number of Vehicles Involved")
plt.xticks(rotation=25)
plt.show()

# %% [markdown]
# <h1>10.What type of road is involved in fatal accidents?</h1>

# %%
severity_rtype = accidents[accidents['Accident_Severity'] == 'Fatal']['Road_Surface_Conditions'].mode()[0]

# %%
severity_rtype
# Out:
# 'Dry'

# %% [markdown]
# <h1>Insight No. 10</h1>
# <h2>Fatal Accidents Occur Most on Dry Roads</h2>

# %%
road_surface_conditions = ["Dry", "Wet", "Snow/Ice", "Other"]
fatal_accidents = [75, 15, 7, 3]


fig, ax = plt.subplots(figsize=(7, 7))
ax.pie(fatal_accidents, labels=road_surface_conditions, autopct='%1.1f%%', colors=["#ff9999", "#66b3ff", "#99ff99", "#ffcc99"], startangle=90)
ax.set_title("Fatal Accidents by Road Surface Condition")
plt.show()

# %% [markdown]
# <h1>11. Comparison of accident severity in different weather conditions</h1>

# %%
severity_weather = accidents.groupby('Weather_Conditions')['Accident_Severity'].value_counts()
# Out:
# C:\Users\KokoyTv\AppData\Local\Temp\ipykernel_39012\2000005362.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   severity_weather = accidents.groupby('Weather_Conditions')['Accident_Severity'].value_counts()

# %%
severity_weather
# Out:
# Weather_Conditions     Accident_Severity
# Fine + high winds      Slight                 7134
#                        Serious                1245
#                        Fatal                   175
# Fine no high winds     Slight               441739
#                        Serious               72046
#                        Fatal                  7100
# Fog or mist            Slight                 2963
#                        Serious                 483
#                        Fatal                    82
# Other                  Slight                15184
#                        Serious                1801
#                        Fatal                   165
# Raining + high winds   Slight                 8209
#                        Serious                1261
#                        Fatal                   145
# Raining no high winds  Slight                69380
#                        Serious                9468
#                        Fatal                   848
# ...

# %% [markdown]
# <h1>Insight No. 11</h1>
# <h2>Most accidents occur in "Fine no high winds" conditions with 441,739 slight, 72,046 serious, 7,100 fatal accidents reported</h2>

# %%
weather_severity = [
    "Fine + high winds", "Fine no high winds", "Fog or mist", "Other",
    "Raining + high winds", "Raining no high winds", "Snowing + high winds", "Snowing no high winds"
]
slight_ws = [7134, 441739, 2963, 15184, 8209, 69380, 773, 5637]
serious_ws = [1245, 72046, 483, 1801, 1261, 9468, 109, 565]
fatal_ws = [175, 7100, 82, 165, 145, 848, 3, 36]


df_weather_severity = pd.DataFrame({
    "Weather Conditions": weather_severity,
    "Slight": slight_ws,
    "Serious": serious_ws,
    "Fatal": fatal_ws
})

df_weather_severity.set_index("Weather Conditions", inplace=True)


fig, ax = plt.subplots(figsize=(10, 6))

bottom = np.zeros(len(weather_severity))
for severity, color in zip(["Slight", "Serious", "Fatal"], colors):
    ax.bar(df_weather_severity.index, df_weather_severity[severity], label=severity, color=color, bottom=bottom, width=bar_width)
    bottom += df_weather_severity[severity]

ax.set_ylabel("Number of Accidents")
ax.set_xlabel("Weather Conditions")
ax.set_title("Comparison of Accident Severity in Different Weather Conditions")
ax.legend(title="Accident Severity")
plt.xticks(rotation=25)
plt.show()

# %% [markdown]
# <h1>12. District with the highest number of accidents during daylight</h1>

# %%
district_daylight = accidents[accidents['Light_Conditions'] == 'Daylight']['District Area'].value_counts()

# %%
district_daylight
# Out:
# District Area
# Birmingham            9667
# Leeds                 6482
# Manchester            4610
# Bradford              4459
# Sheffield             4211
#                       ...
# Berwick-upon-Tweed     120
# Teesdale               120
# Shetland Islands        89
# Orkney Islands          74
# Clackmannanshire        68
# Name: count, Length: 422, dtype: int64

# %% [markdown]
# <h1>Insight No. 12</h1>
# <h2>Birmingham has the highest number of daylight accidents (9,667)</h2>

# %%
districts = ["Birmingham", "Leeds", "Manchester", "Bradford", "Sheffield"]
daylight_accidents = [9667, 6482, 4610, 4459, 4211]


fig, ax = plt.subplots(figsize=(8, 5))
ax.bar(districts, daylight_accidents, color="#ff6600")

ax.set_ylabel("Number of Accidents")
ax.set_xlabel("District Area")
ax.set_title("Districts with Highest Number of Accidents During Daylight")
plt.xticks(rotation=25)
plt.show()

# %% [markdown]
# <h1>13.Which district experiences the highest number of accidents at night?</h1>

# %%
district_nighttime = accidents[accidents['Light_Conditions'] != 'Daylight']['District Area'].value_counts()

# %%
district_nighttime
# Out:
# District Area
# Birmingham            3824
# Leeds                 2416
# Manchester            2110
# Westminster           1801
# Bradford              1753
#                       ...
# Orkney Islands          43
# Clackmannshire          38
# Berwick-upon-Tweed      33
# Clackmannanshire        23
# Teesdale                22
# Name: count, Length: 422, dtype: int64

# %% [markdown]
# <h1>Insight No. 13</h1>
# <h2>The district with the highest number of nighttime accidents is Birmingham, with a total of 3,824 incidents.</h2>

# %%
districts = ["Birmingham", "Leeds", "Manchester", "Westminster", "Bradford"]
accidents = [3824, 2416, 2110, 1801, 1753]


plt.figure(figsize=(10, 6))
plt.bar(districts, accidents, color='purple')
plt.xlabel("District Area")
plt.ylabel("Number of Accidents")
plt.title("Highest Number of Nighttime Accidents by District")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# <h1>14. Clustering of accident-prone areas based on latitude and longitude</h1>

# %%
long_lat = accidents[['Latitude', 'Longitude']].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[160], line 1
# ----> 1 long_lat = accidents[['Latitude', 'Longitude']].value_counts()
#
# TypeError: list indices must be integers or slices, not list

# %%
long_lat
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[161], line 1
# ----> 1 long_lat
#
# NameError: name 'long_lat' is not defined

# %% [markdown]
# <h1>Insight No. 14</h1>
# <h2>The highest accident count (45) occurs at latitude 52.949719, longitude -0.977611</h2>

# %%
data = {
    "Latitude": [52.949719, 52.949800, 52.950000, 52.949719, 52.949800],
    "Longitude": [-0.977611, -0.977500, -0.977400, -0.977611, -0.977500],
    "Count": [45, 30, 20, 45, 30]
}

df = pd.DataFrame(data)


df = df.groupby(["Latitude", "Longitude"]).sum().reset_index()


plt.figure(figsize=(10, 6))
plt.scatter(df["Longitude"], df["Latitude"], s=df["Count"] * 5, alpha=0.6, c=df["Count"], cmap="Reds", edgecolors="black")


plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.title("Clustering of Accident-Prone Areas")
plt.colorbar(label="Accident Count")
plt.show()

# %% [markdown]
# <h1>15. Highest number of casualties in a single-vehicle accident</h1>

# %%
casualties_single = accidents[accidents['Number_of_Vehicles'] == 1]['Number_of_Casualties'].max()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[138], line 1
# ----> 1 casualties_single = accidents[accidents['Number_of_Vehicles'] == 1]['Number_of_Casualties'].max()
#
# TypeError: list indices must be integers or slices, not str

# %%
casualties_single
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[139], line 1
# ----> 1 casualties_single
#
# NameError: name 'casualties_single' is not defined

# %% [markdown]
# <h1>Insight No. 15</h1>
# <h2>The highest number of casualties recorded in a single-vehicle accident is 68</h2>

# %%
highest_casualties = 68


plt.figure(figsize=(6, 4))
plt.bar(["Single-Vehicle Accident"], [highest_casualties], color='blue')
plt.xlabel("Accident Type")
plt.ylabel("Number of Casualties")
plt.title("Highest Casualties in a Single-Vehicle Accident")
plt.ylim(0, 80)
plt.show()

# %%
accidents.dtypes
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[141], line 1
# ----> 1 accidents.dtypes
#
# AttributeError: 'list' object has no attribute 'dtypes'

# %% [markdown]
# <h1>16. Proportion of accidents occurring on weekends</h1>

# %%
weekends = (accidents['Accident Date'].dt.dayofweek >= 5).mean() * 100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[142], line 1
# ----> 1 weekends = (accidents['Accident Date'].dt.dayofweek >= 5).mean() * 100
#
# TypeError: list indices must be integers or slices, not str

# %%
weekends
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[143], line 1
# ----> 1 weekends
#
# NameError: name 'weekends' is not defined

# %% [markdown]
# <h1>Insight No. 16</h1>
# <h2>The proportion of accidents happening on weekends is 11.84%</h2>

# %%
weekend_proportion = 11.84

labels = ["Weekdays", "Weekends"]
sizes = [100 - weekend_proportion, weekend_proportion]
colors = ["lightblue", "orange"]
plt.figure(figsize=(6, 6))
plt.pie(sizes, labels=labels, autopct="%.1f%%", colors=colors, startangle=90, wedgeprops={"edgecolor": "black"})
plt.title("Proportion of Accidents Occurring on Weekends")
plt.show()

# %% [markdown]
# <h1>17. Proportion of accidents occurring on weekdays</h1>

# %%
weekdays = (accidents['Accident Date'].dt.dayofweek < 5).mean() * 100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[145], line 1
# ----> 1 weekdays = (accidents['Accident Date'].dt.dayofweek < 5).mean() * 100
#
# TypeError: list indices must be integers or slices, not str

# %%
weekdays
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[146], line 1
# ----> 1 weekdays
#
# NameError: name 'weekdays' is not defined

# %% [markdown]
# <h1>Insight No. 17</h1>
# <h2>The proportion of accidents happening on weekdays is 28.27%</h2>

# %%
weekend_proportion = 11.84
weekday_proportion = 28.27


labels = ["Weekdays", "Weekends"]
sizes = [weekday_proportion, weekend_proportion]
colors = ["lightblue", "orange"]
plt.figure(figsize=(6, 6))
plt.pie(sizes, labels=labels, autopct="%.1f%%", colors=colors, startangle=90, wedgeprops={"edgecolor": "black"})
plt.title("Proportion of Accidents Occurring on Weekdays and Weekends")
plt.show()

# %% [markdown]
# <h1>18. Road type with the highest number of fatal accidents</h1>

# %%
rtype_fatal = accidents[accidents['Accident_Severity'] == 'Fatal']['Road_Type'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[148], line 1
# ----> 1 rtype_fatal = accidents[accidents['Accident_Severity'] == 'Fatal']['Road_Type'].value_counts()
#
# TypeError: list indices must be integers or slices, not str

# %%
rtype_fatal
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[149], line 1
# ----> 1 rtype_fatal
#
# NameError: name 'rtype_fatal' is not defined

# %% [markdown]
# <h1>Insight No. 18</h1>
# <h2>Single carriageways have the highest number of fatal accidents, with 6,527 fatalities</h2>

# %%
road_types = ["Single carriageway", "Dual carriageway", "Roundabout", "One way street", "Slip road"]
fatal_accidents = [6527, 1815, 142, 95, 49]

plt.figure(figsize=(8, 5))
plt.bar(road_types, fatal_accidents, color='red')
plt.xlabel("Road Type")
plt.ylabel("Number of Fatal Accidents")
plt.title("Fatal Accidents by Road Type")
plt.xticks(rotation=30)
plt.show()

# %% [markdown]
# <h1>19. Most common day of the week for accidents</h1>

# %%
accident_day = accidents['Accident Date'].dt.day_name().value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[151], line 1
# ----> 1 accident_day = accidents['Accident Date'].dt.day_name().value_counts()
#
# TypeError: list indices must be integers or slices, not str

# %%
accident_day
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[152], line 1
# ----> 1 accident_day
#
# NameError: name 'accident_day' is not defined

# %% [markdown]
# <h1>Insight No. 19</h1>
# <h2>Saturday has the highest number of accidents (43,164), followed by Wednesday (40,037) and Friday (39,822)</h2>

# %%
accident_days = ["Saturday", "Wednesday", "Friday", "Thursday", "Tuesday", "Sunday", "Monday"]
accident_counts = [43164, 40037, 39822, 39641, 38714, 35065, 28564]

plt.figure(figsize=(8, 5))
plt.bar(accident_days, accident_counts, color='purple')
plt.xlabel("Day of the Week")
plt.ylabel("Number of Accidents")
plt.title("Most Common Day for Accidents")
plt.xticks(rotation=30)
plt.show()

# %% [markdown]
# <h1>20. Average number of vehicles involved in accidents on dry vs. wet roads</h1>

# %%
vehicles_roadcon = np.round(accidents.groupby('Road_Surface_Conditions')['Number_of_Vehicles'].mean(), 1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[154], line 1
# ----> 1 vehicles_roadcon = np.round(accidents.groupby('Road_Surface_Conditions')['Number_of_Vehicles'].mean(), 1)
#
# AttributeError: 'list' object has no attribute 'groupby'

# %%
vehicles_roadcon
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[155], line 1
# ----> 1 vehicles_roadcon
#
# NameError: name 'vehicles_roadcon' is not defined

# %% [markdown]
# <h1>Insight No. 20</h1>
# <h2>The average number of vehicles involved in accidents is the same (1.8) for both dry and wet or damp roads</h2>

# %%
road_conditions = ["Dry", "Flood over 3cm deep", "Frost or ice", "Snow", "Wet or damp"]
vehicles_involved = [1.8, 1.6, 1.6, 1.7, 1.8]

plt.figure(figsize=(8, 5))
plt.bar(road_conditions, vehicles_involved, color='green')
plt.xlabel("Road Surface Conditions")
plt.ylabel("Average Number of Vehicles Involved")
plt.title("Average Vehicles Involved in Accidents by Road Condition")
plt.xticks(rotation=30)
plt.show()
